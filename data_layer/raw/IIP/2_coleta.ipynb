# %% [markdown]
# # Coleta IIP

# %%
core_indicators = [
    # Headlines
    "NIIP", "TA_AFR", "TL_AFR",
    # Direct Investment
    "D", "D_F5", "D_FL",
    # Portfolio Investment
    "P_MV", "P_F5_MV", "P_F3_MV",
    # Other Investment
    "O_FL1", "O_F4_NV", "O_F2_NV", "O_F81",
    # Reserve Assets
    "R", "R_F11_MV", "R_FK_MV", "R_F12_MV",
    # SDR allocations (passivo, para net de SDR)
    "O_F12",
]

# %%
important_countries = [
    # Maiores economias / benchmarks
    "USA","CHN","DEU","JPN","GBR","FRA","ITA","IND","CAN","AUS","KOR","ESP","NLD",
    # Europa ampliada
    "IRL","CHE","LUX","SWE","DNK","FIN","POL","AUT","BEL","CZE","HUN","ROU","PRT","GRC",
    # Américas (desenvolvidos + EM)
    "BRA","MEX","ARG","COL","CHL","PER","URY",
    # Ásia emergente e manufatura
    "TWN","SGP","HKG","THA","MYS","VNM","IDN","PHL",
    # Oriente Médio / petróleo
    "SAU","ARE","QAT","KWT","IRN","ISR",
    # Commodities avançados / energia
    "NOR","RUS",
    # África (representativos)
    "ZAF","EGY","NGA","GHA","KEN",
]

# %%
import sdmx
import pandas as pd
import os
from pathlib import Path

nome_base = 'IIP'

# Usar caminho absoluto para garantir que funciona independente do CWD
output_dir = Path("/opt/airflow/data_layer/raw/Resultados")

# Cliente IMF
client = sdmx.Client("IMF_DATA")
base = client.dataflow(nome_base)
nome_estrutura = list(base.structure.keys())[0]
estrutura = base.structure[nome_estrutura]

params = dict(
    startPeriod="2000",
)

df_final = pd.DataFrame() 


# Abrir o arquivo para adicionar conteúdo (append)
with open("1_DICIONARIO.txt", "a", encoding="utf-8") as f:

    for country in important_countries:
        f.write("----------------------\n\n")
        for i,core_indicator in enumerate(core_indicators):
            # key = f'BRA+USA+CHN+IND.{indicador}.USD.A'
            key = dict(
                COUNTRY = country,
                # BOP_ACCOUNTING_ENTRY = ac,
                INDICATOR = core_indicator,
                FREQUENCY = "Q",
                # UNIT= "USDB"
            )

            # Baixar os dados
            data_msg = client.data(nome_base, key=key, params=params, dsd=estrutura)

            # Converter para pandas DataFrame
            df = sdmx.to_pandas(
                data_msg, 
                #datetime="TIME_PERIOD"
                )

            df = df.reset_index()

            df_final = pd.concat([df_final, df], ignore_index=True)
            if not df.empty:
                print(f"País {country},indicador: {core_indicator}")
                f.write(f"\nPaís {country},indicador: {core_indicator}")
            print(f"Finalizada etapa {i}") if i == 1 else print

display(df_final.head())

# Salvar usando caminho absoluto
output_file = output_dir / f"{nome_base}.csv"
df_final.to_csv(output_file, index=False)
print(f"✓ Arquivo final salvo com sucesso: {output_file}")
# Out:
# País USA,indicador: NIIP
# País USA,indicador: TA_AFR
# Finalizada etapa 1
# País USA,indicador: TL_AFR
# País USA,indicador: D
# País USA,indicador: D_F5
# País USA,indicador: D_FL
# País USA,indicador: P_MV
# País USA,indicador: P_F5_MV
# País USA,indicador: P_F3_MV
# País USA,indicador: O_FL1
# País USA,indicador: O_F4_NV
# País USA,indicador: O_F2_NV
# País USA,indicador: O_F81
# País USA,indicador: R
# País USA,indicador: R_F11_MV
# País USA,indicador: R_FK_MV
# País USA,indicador: R_F12_MV
# País USA,indicador: O_F12
# País CHN,indicador: NIIP
# País CHN,indicador: TA_AFR
# Finalizada etapa 1
# País CHN,indicador: TL_AFR
# País CHN,indicador: D
# País CHN,indicador: D_F5
# País CHN,indicador: D_FL
# País CHN,indicador: P_MV
# País CHN,indicador: P_F5_MV
# País CHN,indicador: P_F3_MV
# País CHN,indicador: O_FL1
# País CHN,indicador: O_F4_NV
# País CHN,indicador: O_F2_NV
# País CHN,indicador: O_F81
# País CHN,indicador: R
# País CHN,indicador: R_F11_MV
# País CHN,indicador: R_FK_MV
# País CHN,indicador: R_F12_MV
# País CHN,indicador: O_F12
# País DEU,indicador: NIIP
# País DEU,indicador: TA_AFR
# Finalizada etapa 1
# País DEU,indicador: TL_AFR
# País DEU,indicador: D
# País DEU,indicador: D_F5
# País DEU,indicador: D_FL
# País DEU,indicador: P_MV
# País DEU,indicador: P_F5_MV
# País DEU,indicador: P_F3_MV
# País DEU,indicador: O_FL1
# País DEU,indicador: O_F4_NV
# País DEU,indicador: O_F2_NV
# País DEU,indicador: O_F81
# País DEU,indicador: R
# País DEU,indicador: R_F11_MV
# País DEU,indicador: R_FK_MV
# País DEU,indicador: R_F12_MV
# País DEU,indicador: O_F12
# País JPN,indicador: NIIP
# País JPN,indicador: TA_AFR
# Finalizada etapa 1
# País JPN,indicador: TL_AFR
# País JPN,indicador: D
# País JPN,indicador: D_F5
# País JPN,indicador: D_FL
# País JPN,indicador: P_MV
# País JPN,indicador: P_F5_MV
# País JPN,indicador: P_F3_MV
# País JPN,indicador: O_FL1
# País JPN,indicador: O_F4_NV
# País JPN,indicador: O_F2_NV
# País JPN,indicador: O_F81
# País JPN,indicador: R
# País JPN,indicador: R_F11_MV
# País JPN,indicador: R_FK_MV
# País JPN,indicador: R_F12_MV
# País JPN,indicador: O_F12
# País GBR,indicador: NIIP
# País GBR,indicador: TA_AFR
# Finalizada etapa 1
# País GBR,indicador: TL_AFR
# País GBR,indicador: D
# País GBR,indicador: D_F5
# País GBR,indicador: D_FL
# País GBR,indicador: P_MV
# País GBR,indicador: P_F5_MV
# País GBR,indicador: P_F3_MV
# País GBR,indicador: O_FL1
# País GBR,indicador: O_F4_NV
# País GBR,indicador: O_F2_NV
# País GBR,indicador: O_F81
# País GBR,indicador: R
# País GBR,indicador: R_F11_MV
# País GBR,indicador: R_FK_MV
# País GBR,indicador: R_F12_MV
# País GBR,indicador: O_F12
# País FRA,indicador: NIIP
# País FRA,indicador: TA_AFR
# Finalizada etapa 1
# País FRA,indicador: TL_AFR
# País FRA,indicador: D
# País FRA,indicador: D_F5
# País FRA,indicador: D_FL
# País FRA,indicador: P_MV
# País FRA,indicador: P_F5_MV
# País FRA,indicador: P_F3_MV
# País FRA,indicador: O_FL1
# País FRA,indicador: O_F4_NV
# País FRA,indicador: O_F2_NV
# País FRA,indicador: O_F81
# País FRA,indicador: R
# País FRA,indicador: R_F11_MV
# País FRA,indicador: R_FK_MV
# País FRA,indicador: R_F12_MV
# País FRA,indicador: O_F12
# País ITA,indicador: NIIP
# País ITA,indicador: TA_AFR
# Finalizada etapa 1
# País ITA,indicador: TL_AFR
# País ITA,indicador: D
# País ITA,indicador: D_F5
# País ITA,indicador: D_FL
# País ITA,indicador: P_MV
# País ITA,indicador: P_F5_MV
# País ITA,indicador: P_F3_MV
# País ITA,indicador: O_FL1
# País ITA,indicador: O_F4_NV
# País ITA,indicador: O_F2_NV
# País ITA,indicador: O_F81
# País ITA,indicador: R
# País ITA,indicador: R_F11_MV
# País ITA,indicador: R_FK_MV
# País ITA,indicador: R_F12_MV
# País ITA,indicador: O_F12
# País IND,indicador: NIIP
# País IND,indicador: TA_AFR
# Finalizada etapa 1
# País IND,indicador: TL_AFR
# País IND,indicador: D
# País IND,indicador: D_F5
# País IND,indicador: D_FL
# País IND,indicador: P_MV
# País IND,indicador: P_F5_MV
# País IND,indicador: P_F3_MV
# País IND,indicador: O_FL1
# País IND,indicador: O_F4_NV
# País IND,indicador: O_F2_NV
# País IND,indicador: O_F81
# País IND,indicador: R
# País IND,indicador: R_F11_MV
# País IND,indicador: R_FK_MV
# País IND,indicador: R_F12_MV
# País IND,indicador: O_F12
# País CAN,indicador: NIIP
# País CAN,indicador: TA_AFR
# Finalizada etapa 1
# País CAN,indicador: TL_AFR
# País CAN,indicador: D
# País CAN,indicador: D_F5
# País CAN,indicador: D_FL
# País CAN,indicador: P_MV
# País CAN,indicador: P_F5_MV
# País CAN,indicador: P_F3_MV
# País CAN,indicador: O_FL1
# País CAN,indicador: O_F4_NV
# País CAN,indicador: O_F2_NV
# País CAN,indicador: O_F81
# País CAN,indicador: R
# País CAN,indicador: R_F11_MV
# País CAN,indicador: R_FK_MV
# País CAN,indicador: R_F12_MV
# País CAN,indicador: O_F12
# País AUS,indicador: NIIP
# País AUS,indicador: TA_AFR
# Finalizada etapa 1
# País AUS,indicador: TL_AFR
# País AUS,indicador: D
# País AUS,indicador: D_F5
# País AUS,indicador: D_FL
# País AUS,indicador: P_MV
# País AUS,indicador: P_F5_MV
# País AUS,indicador: P_F3_MV
# País AUS,indicador: O_FL1
# País AUS,indicador: O_F4_NV
# País AUS,indicador: O_F2_NV
# País AUS,indicador: O_F81
# País AUS,indicador: R
# País AUS,indicador: R_F11_MV
# País AUS,indicador: R_FK_MV
# País AUS,indicador: R_F12_MV
# País AUS,indicador: O_F12
# País KOR,indicador: NIIP
# País KOR,indicador: TA_AFR
# Finalizada etapa 1
# País KOR,indicador: TL_AFR
# País KOR,indicador: D
# País KOR,indicador: D_F5
# País KOR,indicador: D_FL
# País KOR,indicador: P_MV
# País KOR,indicador: P_F5_MV
# País KOR,indicador: P_F3_MV
# País KOR,indicador: O_FL1
# País KOR,indicador: O_F4_NV
# País KOR,indicador: O_F2_NV
# País KOR,indicador: O_F81
# País KOR,indicador: R
# País KOR,indicador: R_F11_MV
# País KOR,indicador: R_FK_MV
# País KOR,indicador: R_F12_MV
# País KOR,indicador: O_F12
# País ESP,indicador: NIIP
# País ESP,indicador: TA_AFR
# Finalizada etapa 1
# País ESP,indicador: TL_AFR
# País ESP,indicador: D
# País ESP,indicador: D_F5
# País ESP,indicador: D_FL
# País ESP,indicador: P_MV
# País ESP,indicador: P_F5_MV
# País ESP,indicador: P_F3_MV
# País ESP,indicador: O_FL1
# País ESP,indicador: O_F4_NV
# País ESP,indicador: O_F2_NV
# País ESP,indicador: O_F81
# País ESP,indicador: R
# País ESP,indicador: R_F11_MV
# País ESP,indicador: R_FK_MV
# País ESP,indicador: R_F12_MV
# País ESP,indicador: O_F12
# País NLD,indicador: NIIP
# País NLD,indicador: TA_AFR
# Finalizada etapa 1
# País NLD,indicador: TL_AFR
# País NLD,indicador: D
# País NLD,indicador: D_F5
# País NLD,indicador: D_FL
# País NLD,indicador: P_MV
# País NLD,indicador: P_F5_MV
# País NLD,indicador: P_F3_MV
# País NLD,indicador: O_FL1
# País NLD,indicador: O_F4_NV
# País NLD,indicador: O_F2_NV
# País NLD,indicador: O_F81
# País NLD,indicador: R
# País NLD,indicador: R_F11_MV
# País NLD,indicador: R_FK_MV
# País NLD,indicador: R_F12_MV
# País NLD,indicador: O_F12
# País IRL,indicador: NIIP
# País IRL,indicador: TA_AFR
# Finalizada etapa 1
# País IRL,indicador: TL_AFR
# País IRL,indicador: D
# País IRL,indicador: D_F5
# País IRL,indicador: D_FL
# País IRL,indicador: P_MV
# País IRL,indicador: P_F5_MV
# País IRL,indicador: P_F3_MV
# País IRL,indicador: O_FL1
# País IRL,indicador: O_F4_NV
# País IRL,indicador: O_F2_NV
# País IRL,indicador: O_F81
# País IRL,indicador: R
# País IRL,indicador: R_F11_MV
# País IRL,indicador: R_FK_MV
# País IRL,indicador: R_F12_MV
# País IRL,indicador: O_F12
# País CHE,indicador: NIIP
# País CHE,indicador: TA_AFR
# Finalizada etapa 1
# País CHE,indicador: TL_AFR
# País CHE,indicador: D
# País CHE,indicador: D_F5
# País CHE,indicador: D_FL
# País CHE,indicador: P_MV
# País CHE,indicador: P_F5_MV
# País CHE,indicador: P_F3_MV
# País CHE,indicador: O_FL1
# País CHE,indicador: O_F4_NV
# País CHE,indicador: O_F2_NV
# País CHE,indicador: O_F81
# País CHE,indicador: R
# País CHE,indicador: R_F11_MV
# País CHE,indicador: R_FK_MV
# País CHE,indicador: R_F12_MV
# País CHE,indicador: O_F12
# País LUX,indicador: NIIP
# País LUX,indicador: TA_AFR
# Finalizada etapa 1
# País LUX,indicador: TL_AFR
# País LUX,indicador: D
# País LUX,indicador: D_F5
# País LUX,indicador: D_FL
# País LUX,indicador: P_MV
# País LUX,indicador: P_F5_MV
# País LUX,indicador: P_F3_MV
# País LUX,indicador: O_FL1
# País LUX,indicador: O_F4_NV
# País LUX,indicador: O_F2_NV
# País LUX,indicador: O_F81
# País LUX,indicador: R
# País LUX,indicador: R_F11_MV
# País LUX,indicador: R_FK_MV
# País LUX,indicador: R_F12_MV
# País LUX,indicador: O_F12
# País SWE,indicador: NIIP
# País SWE,indicador: TA_AFR
# Finalizada etapa 1
# País SWE,indicador: TL_AFR
# País SWE,indicador: D
# País SWE,indicador: D_F5
# País SWE,indicador: D_FL
# País SWE,indicador: P_MV
# País SWE,indicador: P_F5_MV
# País SWE,indicador: P_F3_MV
# País SWE,indicador: O_FL1
# País SWE,indicador: O_F4_NV
# País SWE,indicador: O_F2_NV
# País SWE,indicador: O_F81
# País SWE,indicador: R
# País SWE,indicador: R_F11_MV
# País SWE,indicador: R_FK_MV
# País SWE,indicador: R_F12_MV
# País SWE,indicador: O_F12
# País DNK,indicador: NIIP
# País DNK,indicador: TA_AFR
# Finalizada etapa 1
# País DNK,indicador: TL_AFR
# País DNK,indicador: D
# País DNK,indicador: D_F5
# País DNK,indicador: D_FL
# País DNK,indicador: P_MV
# País DNK,indicador: P_F5_MV
# País DNK,indicador: P_F3_MV
# País DNK,indicador: O_FL1
# País DNK,indicador: O_F4_NV
# País DNK,indicador: O_F2_NV
# País DNK,indicador: O_F81
# País DNK,indicador: R
# País DNK,indicador: R_F11_MV
# País DNK,indicador: R_FK_MV
# País DNK,indicador: R_F12_MV
# País DNK,indicador: O_F12
# País FIN,indicador: NIIP
# País FIN,indicador: TA_AFR
# Finalizada etapa 1
# País FIN,indicador: TL_AFR
# País FIN,indicador: D
# País FIN,indicador: D_F5
# País FIN,indicador: D_FL
# País FIN,indicador: P_MV
# País FIN,indicador: P_F5_MV
# País FIN,indicador: P_F3_MV
# País FIN,indicador: O_FL1
# País FIN,indicador: O_F4_NV
# País FIN,indicador: O_F2_NV
# País FIN,indicador: O_F81
# País FIN,indicador: R
# País FIN,indicador: R_F11_MV
# País FIN,indicador: R_FK_MV
# País FIN,indicador: R_F12_MV
# País FIN,indicador: O_F12
# País POL,indicador: NIIP
# País POL,indicador: TA_AFR
# Finalizada etapa 1
# País POL,indicador: TL_AFR
# País POL,indicador: D
# País POL,indicador: D_F5
# País POL,indicador: D_FL
# País POL,indicador: P_MV
# País POL,indicador: P_F5_MV
# País POL,indicador: P_F3_MV
# País POL,indicador: O_FL1
# País POL,indicador: O_F4_NV
# País POL,indicador: O_F2_NV
# País POL,indicador: O_F81
# País POL,indicador: R
# País POL,indicador: R_F11_MV
# País POL,indicador: R_FK_MV
# País POL,indicador: R_F12_MV
# País POL,indicador: O_F12
# País AUT,indicador: NIIP
# País AUT,indicador: TA_AFR
# Finalizada etapa 1
# País AUT,indicador: TL_AFR
# País AUT,indicador: D
# País AUT,indicador: D_F5
# País AUT,indicador: D_FL
# País AUT,indicador: P_MV
# País AUT,indicador: P_F5_MV
# País AUT,indicador: P_F3_MV
# País AUT,indicador: O_FL1
# País AUT,indicador: O_F4_NV
# País AUT,indicador: O_F2_NV
# País AUT,indicador: O_F81
# País AUT,indicador: R
# País AUT,indicador: R_F11_MV
# País AUT,indicador: R_FK_MV
# País AUT,indicador: R_F12_MV
# País AUT,indicador: O_F12
# País BEL,indicador: NIIP
# País BEL,indicador: TA_AFR
# Finalizada etapa 1
# País BEL,indicador: TL_AFR
# País BEL,indicador: D
# País BEL,indicador: D_F5
# País BEL,indicador: D_FL
# País BEL,indicador: P_MV
# País BEL,indicador: P_F5_MV
# País BEL,indicador: P_F3_MV
# País BEL,indicador: O_FL1
# País BEL,indicador: O_F4_NV
# País BEL,indicador: O_F2_NV
# País BEL,indicador: O_F81
# País BEL,indicador: R
# País BEL,indicador: R_F11_MV
# País BEL,indicador: R_FK_MV
# País BEL,indicador: R_F12_MV
# País BEL,indicador: O_F12
# País CZE,indicador: NIIP
# País CZE,indicador: TA_AFR
# Finalizada etapa 1
# País CZE,indicador: TL_AFR
# País CZE,indicador: D
# País CZE,indicador: D_F5
# País CZE,indicador: D_FL
# País CZE,indicador: P_MV
# País CZE,indicador: P_F5_MV
# País CZE,indicador: P_F3_MV
# País CZE,indicador: O_FL1
# País CZE,indicador: O_F4_NV
# País CZE,indicador: O_F2_NV
# País CZE,indicador: O_F81
# País CZE,indicador: R
# País CZE,indicador: R_F11_MV
# País CZE,indicador: R_FK_MV
# País CZE,indicador: R_F12_MV
# País CZE,indicador: O_F12
# País HUN,indicador: NIIP
# País HUN,indicador: TA_AFR
# Finalizada etapa 1
# País HUN,indicador: TL_AFR
# País HUN,indicador: D
# País HUN,indicador: D_F5
# País HUN,indicador: D_FL
# País HUN,indicador: P_MV
# País HUN,indicador: P_F5_MV
# País HUN,indicador: P_F3_MV
# País HUN,indicador: O_FL1
# País HUN,indicador: O_F4_NV
# País HUN,indicador: O_F2_NV
# País HUN,indicador: O_F81
# País HUN,indicador: R
# País HUN,indicador: R_F11_MV
# País HUN,indicador: R_FK_MV
# País HUN,indicador: R_F12_MV
# País HUN,indicador: O_F12
# País ROU,indicador: NIIP
# País ROU,indicador: TA_AFR
# Finalizada etapa 1
# País ROU,indicador: TL_AFR
# País ROU,indicador: D
# País ROU,indicador: D_F5
# País ROU,indicador: D_FL
# País ROU,indicador: P_MV
# País ROU,indicador: P_F5_MV
# País ROU,indicador: P_F3_MV
# País ROU,indicador: O_FL1
# País ROU,indicador: O_F4_NV
# País ROU,indicador: O_F2_NV
# País ROU,indicador: O_F81
# País ROU,indicador: R
# País ROU,indicador: R_F11_MV
# País ROU,indicador: R_FK_MV
# País ROU,indicador: R_F12_MV
# País ROU,indicador: O_F12
# País PRT,indicador: NIIP
# País PRT,indicador: TA_AFR
# Finalizada etapa 1
# País PRT,indicador: TL_AFR
# País PRT,indicador: D
# País PRT,indicador: D_F5
# País PRT,indicador: D_FL
# País PRT,indicador: P_MV
# País PRT,indicador: P_F5_MV
# País PRT,indicador: P_F3_MV
# País PRT,indicador: O_FL1
# País PRT,indicador: O_F4_NV
# País PRT,indicador: O_F2_NV
# País PRT,indicador: O_F81
# País PRT,indicador: R
# País PRT,indicador: R_F11_MV
# País PRT,indicador: R_FK_MV
# País PRT,indicador: R_F12_MV
# País PRT,indicador: O_F12
# País GRC,indicador: NIIP
# País GRC,indicador: TA_AFR
# Finalizada etapa 1
# País GRC,indicador: TL_AFR
# País GRC,indicador: D
# País GRC,indicador: D_F5
# País GRC,indicador: D_FL
# País GRC,indicador: P_MV
# País GRC,indicador: P_F5_MV
# País GRC,indicador: P_F3_MV
# País GRC,indicador: O_FL1
# País GRC,indicador: O_F4_NV
# País GRC,indicador: O_F2_NV
# País GRC,indicador: O_F81
# País GRC,indicador: R
# País GRC,indicador: R_F11_MV
# País GRC,indicador: R_FK_MV
# País GRC,indicador: R_F12_MV
# País GRC,indicador: O_F12
# País BRA,indicador: NIIP
# País BRA,indicador: TA_AFR
# Finalizada etapa 1
# País BRA,indicador: TL_AFR
# País BRA,indicador: D
# País BRA,indicador: D_F5
# País BRA,indicador: D_FL
# País BRA,indicador: P_MV
# País BRA,indicador: P_F5_MV
# País BRA,indicador: P_F3_MV
# País BRA,indicador: O_FL1
# País BRA,indicador: O_F4_NV
# País BRA,indicador: O_F2_NV
# País BRA,indicador: O_F81
# País BRA,indicador: R
# País BRA,indicador: R_F11_MV
# País BRA,indicador: R_FK_MV
# País BRA,indicador: R_F12_MV
# País BRA,indicador: O_F12
# País MEX,indicador: NIIP
# País MEX,indicador: TA_AFR
# Finalizada etapa 1
# País MEX,indicador: TL_AFR
# País MEX,indicador: D
# País MEX,indicador: D_F5
# País MEX,indicador: D_FL
# País MEX,indicador: P_MV
# País MEX,indicador: P_F5_MV
# País MEX,indicador: P_F3_MV
# País MEX,indicador: O_FL1
# País MEX,indicador: O_F4_NV
# País MEX,indicador: O_F2_NV
# País MEX,indicador: O_F81
# País MEX,indicador: R
# País MEX,indicador: R_F11_MV
# País MEX,indicador: R_FK_MV
# País MEX,indicador: R_F12_MV
# País MEX,indicador: O_F12
# País ARG,indicador: NIIP
# País ARG,indicador: TA_AFR
# Finalizada etapa 1
# País ARG,indicador: TL_AFR
# País ARG,indicador: D
# País ARG,indicador: D_F5
# País ARG,indicador: D_FL
# País ARG,indicador: P_MV
# País ARG,indicador: P_F5_MV
# País ARG,indicador: P_F3_MV
# País ARG,indicador: O_FL1
# País ARG,indicador: O_F4_NV
# País ARG,indicador: O_F2_NV
# País ARG,indicador: O_F81
# País ARG,indicador: R
# País ARG,indicador: R_F11_MV
# País ARG,indicador: R_FK_MV
# País ARG,indicador: R_F12_MV
# País ARG,indicador: O_F12
# País COL,indicador: NIIP
# País COL,indicador: TA_AFR
# Finalizada etapa 1
# País COL,indicador: TL_AFR
# País COL,indicador: D
# País COL,indicador: D_F5
# País COL,indicador: D_FL
# País COL,indicador: P_MV
# País COL,indicador: P_F5_MV
# País COL,indicador: P_F3_MV
# País COL,indicador: O_FL1
# País COL,indicador: O_F4_NV
# País COL,indicador: O_F2_NV
# País COL,indicador: O_F81
# País COL,indicador: R
# País COL,indicador: R_F11_MV
# País COL,indicador: R_FK_MV
# País COL,indicador: R_F12_MV
# País COL,indicador: O_F12
# País CHL,indicador: NIIP
# País CHL,indicador: TA_AFR
# Finalizada etapa 1
# País CHL,indicador: TL_AFR
# País CHL,indicador: D
# País CHL,indicador: D_F5
# País CHL,indicador: D_FL
# País CHL,indicador: P_MV
# País CHL,indicador: P_F5_MV
# País CHL,indicador: P_F3_MV
# País CHL,indicador: O_FL1
# País CHL,indicador: O_F4_NV
# País CHL,indicador: O_F2_NV
# País CHL,indicador: O_F81
# País CHL,indicador: R
# País CHL,indicador: R_F11_MV
# País CHL,indicador: R_FK_MV
# País CHL,indicador: R_F12_MV
# País CHL,indicador: O_F12
# País PER,indicador: NIIP
# País PER,indicador: TA_AFR
# Finalizada etapa 1
# País PER,indicador: TL_AFR
# País PER,indicador: D
# País PER,indicador: D_F5
# País PER,indicador: D_FL
# País PER,indicador: P_MV
# País PER,indicador: P_F5_MV
# País PER,indicador: P_F3_MV
# País PER,indicador: O_FL1
# País PER,indicador: O_F4_NV
# País PER,indicador: O_F2_NV
# País PER,indicador: O_F81
# País PER,indicador: R
# País PER,indicador: R_F11_MV
# País PER,indicador: R_FK_MV
# País PER,indicador: R_F12_MV
# País PER,indicador: O_F12
# País URY,indicador: NIIP
# País URY,indicador: TA_AFR
# Finalizada etapa 1
# País URY,indicador: TL_AFR
# País URY,indicador: D
# País URY,indicador: D_F5
# País URY,indicador: D_FL
# País URY,indicador: P_MV
# País URY,indicador: P_F5_MV
# País URY,indicador: P_F3_MV
# País URY,indicador: O_FL1
# País URY,indicador: O_F4_NV
# País URY,indicador: O_F2_NV
# País URY,indicador: O_F81
# País URY,indicador: R
# País URY,indicador: R_F11_MV
# País URY,indicador: R_FK_MV
# País URY,indicador: R_F12_MV
# País URY,indicador: O_F12
# Finalizada etapa 1
# País SGP,indicador: NIIP
# País SGP,indicador: TA_AFR
# Finalizada etapa 1
# País SGP,indicador: TL_AFR
# País SGP,indicador: D
# País SGP,indicador: D_F5
# País SGP,indicador: D_FL
# País SGP,indicador: P_MV
# País SGP,indicador: P_F5_MV
# País SGP,indicador: P_F3_MV
# País SGP,indicador: O_FL1
# País SGP,indicador: O_F4_NV
# País SGP,indicador: O_F2_NV
# País SGP,indicador: O_F81
# País SGP,indicador: R
# País SGP,indicador: R_FK_MV
# País SGP,indicador: R_F12_MV
# País SGP,indicador: O_F12
# País HKG,indicador: NIIP
# País HKG,indicador: TA_AFR
# Finalizada etapa 1
# País HKG,indicador: TL_AFR
# País HKG,indicador: D
# País HKG,indicador: D_F5
# País HKG,indicador: D_FL
# País HKG,indicador: P_MV
# País HKG,indicador: P_F5_MV
# País HKG,indicador: P_F3_MV
# País HKG,indicador: O_FL1
# País HKG,indicador: O_F4_NV
# País HKG,indicador: O_F2_NV
# País HKG,indicador: O_F81
# País HKG,indicador: R
# País HKG,indicador: R_F11_MV
# País HKG,indicador: R_FK_MV
# País THA,indicador: NIIP
# País THA,indicador: TA_AFR
# Finalizada etapa 1
# País THA,indicador: TL_AFR
# País THA,indicador: D
# País THA,indicador: D_F5
# País THA,indicador: D_FL
# País THA,indicador: P_MV
# País THA,indicador: P_F5_MV
# País THA,indicador: P_F3_MV
# País THA,indicador: O_FL1
# País THA,indicador: O_F4_NV
# País THA,indicador: O_F2_NV
# País THA,indicador: O_F81
# País THA,indicador: R
# País THA,indicador: R_F11_MV
# País THA,indicador: R_FK_MV
# País THA,indicador: R_F12_MV
# País THA,indicador: O_F12
# País MYS,indicador: NIIP
# País MYS,indicador: TA_AFR
# Finalizada etapa 1
# País MYS,indicador: TL_AFR
# País MYS,indicador: D
# País MYS,indicador: D_F5
# País MYS,indicador: D_FL
# País MYS,indicador: P_MV
# País MYS,indicador: P_F5_MV
# País MYS,indicador: P_F3_MV
# País MYS,indicador: O_FL1
# País MYS,indicador: O_F4_NV
# País MYS,indicador: O_F2_NV
# País MYS,indicador: O_F81
# País MYS,indicador: R
# País MYS,indicador: R_FK_MV
# País MYS,indicador: R_F12_MV
# País MYS,indicador: O_F12
# Finalizada etapa 1
# País IDN,indicador: NIIP
# País IDN,indicador: TA_AFR
# Finalizada etapa 1
# País IDN,indicador: TL_AFR
# País IDN,indicador: D
# País IDN,indicador: D_F5
# País IDN,indicador: D_FL
# País IDN,indicador: P_MV
# País IDN,indicador: P_F5_MV
# País IDN,indicador: P_F3_MV
# País IDN,indicador: O_FL1
# País IDN,indicador: O_F4_NV
# País IDN,indicador: O_F2_NV
# País IDN,indicador: O_F81
# País IDN,indicador: R
# País IDN,indicador: R_F11_MV
# País IDN,indicador: R_FK_MV
# País IDN,indicador: R_F12_MV
# País IDN,indicador: O_F12
# País PHL,indicador: NIIP
# País PHL,indicador: TA_AFR
# Finalizada etapa 1
# País PHL,indicador: TL_AFR
# País PHL,indicador: D
# País PHL,indicador: D_F5
# País PHL,indicador: D_FL
# País PHL,indicador: P_MV
# País PHL,indicador: P_F5_MV
# País PHL,indicador: P_F3_MV
# País PHL,indicador: O_FL1
# País PHL,indicador: O_F4_NV
# País PHL,indicador: O_F2_NV
# País PHL,indicador: O_F81
# País PHL,indicador: R
# País PHL,indicador: R_F11_MV
# País PHL,indicador: R_FK_MV
# País PHL,indicador: R_F12_MV
# País PHL,indicador: O_F12
# País SAU,indicador: NIIP
# País SAU,indicador: TA_AFR
# Finalizada etapa 1
# País SAU,indicador: TL_AFR
# País SAU,indicador: D
# País SAU,indicador: P_MV
# País SAU,indicador: P_F5_MV
# País SAU,indicador: P_F3_MV
# País SAU,indicador: O_FL1
# País SAU,indicador: O_F4_NV
# País SAU,indicador: O_F2_NV
# País SAU,indicador: O_F81
# País SAU,indicador: R
# País SAU,indicador: R_F11_MV
# País SAU,indicador: R_FK_MV
# País SAU,indicador: R_F12_MV
# País SAU,indicador: O_F12
# Finalizada etapa 1
# Finalizada etapa 1
# País KWT,indicador: NIIP
# País KWT,indicador: TA_AFR
# Finalizada etapa 1
# País KWT,indicador: TL_AFR
# País KWT,indicador: D
# País KWT,indicador: D_F5
# País KWT,indicador: D_FL
# País KWT,indicador: P_MV
# País KWT,indicador: P_F5_MV
# País KWT,indicador: P_F3_MV
# País KWT,indicador: O_FL1
# País KWT,indicador: O_F4_NV
# País KWT,indicador: O_F2_NV
# País KWT,indicador: O_F81
# País KWT,indicador: R
# País KWT,indicador: R_F11_MV
# País KWT,indicador: R_FK_MV
# País KWT,indicador: R_F12_MV
# País KWT,indicador: O_F12
# Finalizada etapa 1
# País ISR,indicador: NIIP
# País ISR,indicador: TA_AFR
# Finalizada etapa 1
# País ISR,indicador: TL_AFR
# País ISR,indicador: D
# País ISR,indicador: D_F5
# País ISR,indicador: D_FL
# País ISR,indicador: P_MV
# País ISR,indicador: P_F5_MV
# País ISR,indicador: P_F3_MV
# País ISR,indicador: O_FL1
# País ISR,indicador: O_F4_NV
# País ISR,indicador: O_F2_NV
# País ISR,indicador: O_F81
# País ISR,indicador: R
# País ISR,indicador: R_F11_MV
# País ISR,indicador: R_FK_MV
# País ISR,indicador: R_F12_MV
# País ISR,indicador: O_F12
# País NOR,indicador: NIIP
# País NOR,indicador: TA_AFR
# Finalizada etapa 1
# País NOR,indicador: TL_AFR
# País NOR,indicador: D
# País NOR,indicador: D_F5
# País NOR,indicador: D_FL
# País NOR,indicador: P_MV
# País NOR,indicador: P_F5_MV
# País NOR,indicador: P_F3_MV
# País NOR,indicador: O_FL1
# País NOR,indicador: O_F4_NV
# País NOR,indicador: O_F2_NV
# País NOR,indicador: O_F81
# País NOR,indicador: R
# País NOR,indicador: R_FK_MV
# País NOR,indicador: R_F12_MV
# País NOR,indicador: O_F12
# País RUS,indicador: NIIP
# País RUS,indicador: TA_AFR
# Finalizada etapa 1
# País RUS,indicador: TL_AFR
# País RUS,indicador: D
# País RUS,indicador: D_F5
# País RUS,indicador: D_FL
# País RUS,indicador: P_MV
# País RUS,indicador: P_F5_MV
# País RUS,indicador: P_F3_MV
# País RUS,indicador: O_FL1
# País RUS,indicador: O_F4_NV
# País RUS,indicador: O_F2_NV
# País RUS,indicador: O_F81
# País RUS,indicador: R
# País RUS,indicador: R_F11_MV
# País RUS,indicador: R_FK_MV
# País RUS,indicador: R_F12_MV
# País RUS,indicador: O_F12
# País ZAF,indicador: NIIP
# País ZAF,indicador: TA_AFR
# Finalizada etapa 1
# País ZAF,indicador: TL_AFR
# País ZAF,indicador: D
# País ZAF,indicador: D_F5
# País ZAF,indicador: D_FL
# País ZAF,indicador: P_MV
# País ZAF,indicador: P_F5_MV
# País ZAF,indicador: P_F3_MV
# País ZAF,indicador: O_FL1
# País ZAF,indicador: O_F4_NV
# País ZAF,indicador: O_F2_NV
# País ZAF,indicador: R
# País ZAF,indicador: R_F11_MV
# País ZAF,indicador: R_FK_MV
# País ZAF,indicador: R_F12_MV
# País ZAF,indicador: O_F12
# País EGY,indicador: NIIP
# País EGY,indicador: TA_AFR
# Finalizada etapa 1
# País EGY,indicador: TL_AFR
# País EGY,indicador: D
# País EGY,indicador: D_F5
# País EGY,indicador: P_MV
# País EGY,indicador: P_F5_MV
# País EGY,indicador: P_F3_MV
# País EGY,indicador: O_FL1
# País EGY,indicador: O_F4_NV
# País EGY,indicador: O_F2_NV
# País EGY,indicador: O_F81
# País EGY,indicador: R
# País EGY,indicador: R_F11_MV
# País EGY,indicador: R_FK_MV
# País EGY,indicador: R_F12_MV
# País EGY,indicador: O_F12
# País NGA,indicador: NIIP
# País NGA,indicador: TA_AFR
# Finalizada etapa 1
# País NGA,indicador: TL_AFR
# País NGA,indicador: D
# País NGA,indicador: D_F5
# País NGA,indicador: D_FL
# País NGA,indicador: P_MV
# País NGA,indicador: P_F5_MV
# País NGA,indicador: P_F3_MV
# País NGA,indicador: O_FL1
# País NGA,indicador: O_F4_NV
# País NGA,indicador: O_F2_NV
# País NGA,indicador: O_F81
# País NGA,indicador: R
# País NGA,indicador: R_F11_MV
# País NGA,indicador: R_FK_MV
# País NGA,indicador: R_F12_MV
# País NGA,indicador: O_F12
# Finalizada etapa 1
# Finalizada etapa 1
#   COUNTRY BOP_ACCOUNTING_ENTRY INDICATOR UNIT FREQUENCY TIME_PERIOD  \
# 0     USA              NETAL_P      NIIP  USD         Q     2005-Q4
# 1     USA              NETAL_P      NIIP  USD         Q     2006-Q1
# 2     USA              NETAL_P      NIIP  USD         Q     2006-Q2
# 3     USA              NETAL_P      NIIP  USD         Q     2006-Q3
# 4     USA              NETAL_P      NIIP  USD         Q     2006-Q4
#
#           value  index
# 0 -1.857865e+12    NaN
# 1 -1.655616e+12    NaN
# 2 -1.678770e+12    NaN
# 3 -2.005759e+12    NaN
# 4 -1.807819e+12    NaN
