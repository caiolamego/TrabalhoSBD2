# %% [markdown]
# # Coleta BOP

# %%
core_indicators = [
    "CAB", "CABXEF", "KAB", "FAB", "FABXRRI", "EO",
    "SF", "GS", "IN1", "IN2",
    "DXEF", "D_F5", "D_FL",
    "PXEF", "P_F5", "P_F3",
    "O_F4", "O_F2", "O_F81",
    "RUE", "R_F",
]

# %%
important_countries = [
    # Maiores economias / benchmarks
    "USA","CHN","DEU","JPN","GBR","FRA","ITA","IND","CAN","AUS","KOR","ESP","NLD",
    # Europa ampliada
    "IRL","CHE","LUX","SWE","DNK","FIN","POL","AUT","BEL","CZE","HUN","ROU","PRT","GRC",
    # Américas (desenvolvidos + EM)
    "BRA","MEX","ARG","COL","CHL","PER","URY",
    # Ásia emergente e manufatura
    "TWN","SGP","HKG","THA","MYS","VNM","IDN","PHL",
    # Oriente Médio / petróleo
    "SAU","ARE","QAT","KWT","IRN","ISR",
    # Commodities avançados / energia
    "NOR","RUS",
    # África (representativos)
    "ZAF","EGY","NGA","GHA","KEN",
]

# %%
import sdmx
import pandas as pd

nome_base = 'BOP'


# Cliente IMF
client = sdmx.Client("IMF_DATA")
base = client.dataflow(nome_base)
nome_estrutura = list(base.structure.keys())[0]
estrutura = base.structure[nome_estrutura]

params = dict(
    startPeriod="2000",
)

df_final = pd.DataFrame() 


# Abrir o arquivo para adicionar conteúdo (append)
with open("1_DICIONARIO.txt", "a", encoding="utf-8") as f:

    for country in important_countries:
        f.write("----------------------\n\n")
        for i,core_indicator in enumerate(core_indicators):
            # key = f'BRA+USA+CHN+IND.{indicador}.USD.A'
            key = dict(
                COUNTRY = country,
                # BOP_ACCOUNTING_ENTRY = ac,
                INDICATOR = core_indicator,
                FREQUENCY = "Q",
                # UNIT= "USDB"
            )

            # Baixar os dados
            data_msg = client.data(nome_base, key=key, params=params, dsd=estrutura)

            # Converter para pandas DataFrame
            df = sdmx.to_pandas(
                data_msg, 
                #datetime="TIME_PERIOD"
                )

            df = df.reset_index()

            df_final = pd.concat([df_final, df], ignore_index=True)
            if not df.empty:
                print(f"País {country},indicador: {core_indicator}")
                f.write(f"\nPaís {country},indicador: {core_indicator}")
            print(f"Finalizada etapa {i}") if i == 1 else print




display(df_final.head())
df_final.to_csv("/opt/airflow/data_layer/raw/Resultados/BOP.csv", index=False)
# Out:
# País USA,indicador: CAB
# País USA,indicador: CABXEF
# Finalizada etapa 1
# País USA,indicador: KAB
# País USA,indicador: FAB
# País USA,indicador: FABXRRI
# País USA,indicador: EO
# País USA,indicador: SF
# País USA,indicador: GS
# País USA,indicador: IN1
# País USA,indicador: IN2
# País USA,indicador: DXEF
# País USA,indicador: D_F5
# País USA,indicador: D_FL
# País USA,indicador: PXEF
# País USA,indicador: P_F5
# País USA,indicador: P_F3
# País USA,indicador: O_F4
# País USA,indicador: O_F2
# País USA,indicador: O_F81
# País USA,indicador: RUE
# País USA,indicador: R_F
# País CHN,indicador: CAB
# País CHN,indicador: CABXEF
# Finalizada etapa 1
# País CHN,indicador: KAB
# País CHN,indicador: FAB
# País CHN,indicador: FABXRRI
# País CHN,indicador: EO
# País CHN,indicador: SF
# País CHN,indicador: GS
# País CHN,indicador: IN1
# País CHN,indicador: IN2
# País CHN,indicador: DXEF
# País CHN,indicador: D_F5
# País CHN,indicador: D_FL
# País CHN,indicador: PXEF
# País CHN,indicador: P_F5
# País CHN,indicador: P_F3
# País CHN,indicador: O_F4
# País CHN,indicador: O_F2
# País CHN,indicador: O_F81
# País CHN,indicador: RUE
# País CHN,indicador: R_F
# País DEU,indicador: CAB
# País DEU,indicador: CABXEF
# Finalizada etapa 1
# País DEU,indicador: KAB
# País DEU,indicador: FAB
# País DEU,indicador: FABXRRI
# País DEU,indicador: EO
# País DEU,indicador: SF
# País DEU,indicador: GS
# País DEU,indicador: IN1
# País DEU,indicador: IN2
# País DEU,indicador: DXEF
# País DEU,indicador: D_F5
# País DEU,indicador: D_FL
# País DEU,indicador: PXEF
# País DEU,indicador: P_F5
# País DEU,indicador: P_F3
# País DEU,indicador: O_F4
# País DEU,indicador: O_F2
# País DEU,indicador: O_F81
# País DEU,indicador: RUE
# País DEU,indicador: R_F
# País JPN,indicador: CAB
# País JPN,indicador: CABXEF
# Finalizada etapa 1
# País JPN,indicador: KAB
# País JPN,indicador: FAB
# País JPN,indicador: FABXRRI
# País JPN,indicador: EO
# País JPN,indicador: SF
# País JPN,indicador: GS
# País JPN,indicador: IN1
# País JPN,indicador: IN2
# País JPN,indicador: DXEF
# País JPN,indicador: D_F5
# País JPN,indicador: D_FL
# País JPN,indicador: PXEF
# País JPN,indicador: P_F5
# País JPN,indicador: P_F3
# País JPN,indicador: O_F4
# País JPN,indicador: O_F2
# País JPN,indicador: O_F81
# País JPN,indicador: RUE
# País JPN,indicador: R_F
# País GBR,indicador: CAB
# País GBR,indicador: CABXEF
# Finalizada etapa 1
# País GBR,indicador: KAB
# País GBR,indicador: FAB
# País GBR,indicador: FABXRRI
# País GBR,indicador: EO
# País GBR,indicador: SF
# País GBR,indicador: GS
# País GBR,indicador: IN1
# País GBR,indicador: IN2
# País GBR,indicador: DXEF
# País GBR,indicador: D_F5
# País GBR,indicador: D_FL
# País GBR,indicador: PXEF
# País GBR,indicador: P_F5
# País GBR,indicador: P_F3
# País GBR,indicador: O_F4
# País GBR,indicador: O_F2
# País GBR,indicador: O_F81
# País GBR,indicador: RUE
# País GBR,indicador: R_F
# País FRA,indicador: CAB
# País FRA,indicador: CABXEF
# Finalizada etapa 1
# País FRA,indicador: KAB
# País FRA,indicador: FAB
# País FRA,indicador: FABXRRI
# País FRA,indicador: EO
# País FRA,indicador: SF
# País FRA,indicador: GS
# País FRA,indicador: IN1
# País FRA,indicador: IN2
# País FRA,indicador: DXEF
# País FRA,indicador: D_F5
# País FRA,indicador: D_FL
# País FRA,indicador: PXEF
# País FRA,indicador: P_F5
# País FRA,indicador: P_F3
# País FRA,indicador: O_F4
# País FRA,indicador: O_F2
# País FRA,indicador: O_F81
# País FRA,indicador: RUE
# País FRA,indicador: R_F
# País ITA,indicador: CAB
# País ITA,indicador: CABXEF
# Finalizada etapa 1
# País ITA,indicador: KAB
# País ITA,indicador: FAB
# País ITA,indicador: FABXRRI
# País ITA,indicador: EO
# País ITA,indicador: SF
# País ITA,indicador: GS
# País ITA,indicador: IN1
# País ITA,indicador: IN2
# País ITA,indicador: DXEF
# País ITA,indicador: D_F5
# País ITA,indicador: D_FL
# País ITA,indicador: PXEF
# País ITA,indicador: P_F5
# País ITA,indicador: P_F3
# País ITA,indicador: O_F4
# País ITA,indicador: O_F2
# País ITA,indicador: O_F81
# País ITA,indicador: RUE
# País ITA,indicador: R_F
# País IND,indicador: CAB
# País IND,indicador: CABXEF
# Finalizada etapa 1
# País IND,indicador: KAB
# País IND,indicador: FAB
# País IND,indicador: FABXRRI
# País IND,indicador: EO
# País IND,indicador: SF
# País IND,indicador: GS
# País IND,indicador: IN1
# País IND,indicador: IN2
# País IND,indicador: DXEF
# País IND,indicador: D_F5
# País IND,indicador: D_FL
# País IND,indicador: PXEF
# País IND,indicador: P_F5
# País IND,indicador: P_F3
# País IND,indicador: O_F4
# País IND,indicador: O_F2
# País IND,indicador: O_F81
# País IND,indicador: RUE
# País IND,indicador: R_F
# País CAN,indicador: CAB
# País CAN,indicador: CABXEF
# Finalizada etapa 1
# País CAN,indicador: KAB
# País CAN,indicador: FAB
# País CAN,indicador: FABXRRI
# País CAN,indicador: EO
# País CAN,indicador: SF
# País CAN,indicador: GS
# País CAN,indicador: IN1
# País CAN,indicador: IN2
# País CAN,indicador: DXEF
# País CAN,indicador: D_F5
# País CAN,indicador: D_FL
# País CAN,indicador: PXEF
# País CAN,indicador: P_F5
# País CAN,indicador: P_F3
# País CAN,indicador: O_F4
# País CAN,indicador: O_F2
# País CAN,indicador: O_F81
# País CAN,indicador: RUE
# País CAN,indicador: R_F
# País AUS,indicador: CAB
# País AUS,indicador: CABXEF
# Finalizada etapa 1
# País AUS,indicador: KAB
# País AUS,indicador: FAB
# País AUS,indicador: FABXRRI
# País AUS,indicador: EO
# País AUS,indicador: SF
# País AUS,indicador: GS
# País AUS,indicador: IN1
# País AUS,indicador: IN2
# País AUS,indicador: DXEF
# País AUS,indicador: D_F5
# País AUS,indicador: D_FL
# País AUS,indicador: PXEF
# País AUS,indicador: P_F5
# País AUS,indicador: P_F3
# País AUS,indicador: O_F4
# País AUS,indicador: O_F2
# País AUS,indicador: O_F81
# País AUS,indicador: RUE
# País AUS,indicador: R_F
# País KOR,indicador: CAB
# País KOR,indicador: CABXEF
# Finalizada etapa 1
# País KOR,indicador: KAB
# País KOR,indicador: FAB
# País KOR,indicador: FABXRRI
# País KOR,indicador: EO
# País KOR,indicador: SF
# País KOR,indicador: GS
# País KOR,indicador: IN1
# País KOR,indicador: IN2
# País KOR,indicador: DXEF
# País KOR,indicador: D_F5
# País KOR,indicador: D_FL
# País KOR,indicador: PXEF
# País KOR,indicador: P_F5
# País KOR,indicador: P_F3
# País KOR,indicador: O_F4
# País KOR,indicador: O_F2
# País KOR,indicador: O_F81
# País KOR,indicador: RUE
# País KOR,indicador: R_F
# País ESP,indicador: CAB
# País ESP,indicador: CABXEF
# Finalizada etapa 1
# País ESP,indicador: KAB
# País ESP,indicador: FAB
# País ESP,indicador: FABXRRI
# País ESP,indicador: EO
# País ESP,indicador: SF
# País ESP,indicador: GS
# País ESP,indicador: IN1
# País ESP,indicador: IN2
# País ESP,indicador: DXEF
# País ESP,indicador: D_F5
# País ESP,indicador: D_FL
# País ESP,indicador: PXEF
# País ESP,indicador: P_F5
# País ESP,indicador: P_F3
# País ESP,indicador: O_F4
# País ESP,indicador: O_F2
# País ESP,indicador: O_F81
# País ESP,indicador: RUE
# País ESP,indicador: R_F
# País NLD,indicador: CAB
# País NLD,indicador: CABXEF
# Finalizada etapa 1
# País NLD,indicador: KAB
# País NLD,indicador: FAB
# País NLD,indicador: FABXRRI
# País NLD,indicador: EO
# País NLD,indicador: SF
# País NLD,indicador: GS
# País NLD,indicador: IN1
# País NLD,indicador: IN2
# País NLD,indicador: DXEF
# País NLD,indicador: D_F5
# País NLD,indicador: D_FL
# País NLD,indicador: PXEF
# País NLD,indicador: P_F5
# País NLD,indicador: P_F3
# País NLD,indicador: O_F4
# País NLD,indicador: O_F2
# País NLD,indicador: O_F81
# País NLD,indicador: RUE
# País NLD,indicador: R_F
# País IRL,indicador: CAB
# País IRL,indicador: CABXEF
# Finalizada etapa 1
# País IRL,indicador: KAB
# País IRL,indicador: FAB
# País IRL,indicador: FABXRRI
# País IRL,indicador: EO
# País IRL,indicador: SF
# País IRL,indicador: GS
# País IRL,indicador: IN1
# País IRL,indicador: IN2
# País IRL,indicador: DXEF
# País IRL,indicador: D_F5
# País IRL,indicador: D_FL
# País IRL,indicador: PXEF
# País IRL,indicador: P_F5
# País IRL,indicador: P_F3
# País IRL,indicador: O_F4
# País IRL,indicador: O_F2
# País IRL,indicador: O_F81
# País IRL,indicador: RUE
# País IRL,indicador: R_F
# País CHE,indicador: CAB
# País CHE,indicador: CABXEF
# Finalizada etapa 1
# País CHE,indicador: KAB
# País CHE,indicador: FAB
# País CHE,indicador: FABXRRI
# País CHE,indicador: EO
# País CHE,indicador: SF
# País CHE,indicador: GS
# País CHE,indicador: IN1
# País CHE,indicador: IN2
# País CHE,indicador: DXEF
# País CHE,indicador: D_F5
# País CHE,indicador: D_FL
# País CHE,indicador: PXEF
# País CHE,indicador: P_F5
# País CHE,indicador: P_F3
# País CHE,indicador: O_F4
# País CHE,indicador: O_F2
# País CHE,indicador: RUE
# País CHE,indicador: R_F
# País LUX,indicador: CAB
# País LUX,indicador: CABXEF
# Finalizada etapa 1
# País LUX,indicador: KAB
# País LUX,indicador: FAB
# País LUX,indicador: FABXRRI
# País LUX,indicador: EO
# País LUX,indicador: SF
# País LUX,indicador: GS
# País LUX,indicador: IN1
# País LUX,indicador: IN2
# País LUX,indicador: DXEF
# País LUX,indicador: D_F5
# País LUX,indicador: D_FL
# País LUX,indicador: PXEF
# País LUX,indicador: P_F5
# País LUX,indicador: P_F3
# País LUX,indicador: O_F4
# País LUX,indicador: O_F2
# País LUX,indicador: O_F81
# País LUX,indicador: RUE
# País LUX,indicador: R_F
# País SWE,indicador: CAB
# País SWE,indicador: CABXEF
# Finalizada etapa 1
# País SWE,indicador: KAB
# País SWE,indicador: FAB
# País SWE,indicador: FABXRRI
# País SWE,indicador: EO
# País SWE,indicador: SF
# País SWE,indicador: GS
# País SWE,indicador: IN1
# País SWE,indicador: IN2
# País SWE,indicador: DXEF
# País SWE,indicador: D_F5
# País SWE,indicador: D_FL
# País SWE,indicador: PXEF
# País SWE,indicador: P_F5
# País SWE,indicador: P_F3
# País SWE,indicador: O_F4
# País SWE,indicador: O_F2
# País SWE,indicador: O_F81
# País SWE,indicador: RUE
# País SWE,indicador: R_F
# País DNK,indicador: CAB
# País DNK,indicador: CABXEF
# Finalizada etapa 1
# País DNK,indicador: KAB
# País DNK,indicador: FAB
# País DNK,indicador: FABXRRI
# País DNK,indicador: EO
# País DNK,indicador: SF
# País DNK,indicador: GS
# País DNK,indicador: IN1
# País DNK,indicador: IN2
# País DNK,indicador: DXEF
# País DNK,indicador: D_F5
# País DNK,indicador: D_FL
# País DNK,indicador: PXEF
# País DNK,indicador: P_F5
# País DNK,indicador: P_F3
# País DNK,indicador: O_F4
# País DNK,indicador: O_F2
# País DNK,indicador: O_F81
# País DNK,indicador: RUE
# País DNK,indicador: R_F
# País FIN,indicador: CAB
# País FIN,indicador: CABXEF
# Finalizada etapa 1
# País FIN,indicador: KAB
# País FIN,indicador: FAB
# País FIN,indicador: FABXRRI
# País FIN,indicador: EO
# País FIN,indicador: SF
# País FIN,indicador: GS
# País FIN,indicador: IN1
# País FIN,indicador: IN2
# País FIN,indicador: DXEF
# País FIN,indicador: D_F5
# País FIN,indicador: D_FL
# País FIN,indicador: PXEF
# País FIN,indicador: P_F5
# País FIN,indicador: P_F3
# País FIN,indicador: O_F4
# País FIN,indicador: O_F2
# País FIN,indicador: O_F81
# País FIN,indicador: RUE
# País FIN,indicador: R_F
# País POL,indicador: CAB
# País POL,indicador: CABXEF
# Finalizada etapa 1
# País POL,indicador: KAB
# País POL,indicador: FAB
# País POL,indicador: FABXRRI
# País POL,indicador: EO
# País POL,indicador: SF
# País POL,indicador: GS
# País POL,indicador: IN1
# País POL,indicador: IN2
# País POL,indicador: DXEF
# País POL,indicador: D_F5
# País POL,indicador: D_FL
# País POL,indicador: PXEF
# País POL,indicador: P_F5
# País POL,indicador: P_F3
# País POL,indicador: O_F4
# País POL,indicador: O_F2
# País POL,indicador: O_F81
# País POL,indicador: RUE
# País POL,indicador: R_F
# País AUT,indicador: CAB
# País AUT,indicador: CABXEF
# Finalizada etapa 1
# País AUT,indicador: KAB
# País AUT,indicador: FAB
# País AUT,indicador: FABXRRI
# País AUT,indicador: EO
# País AUT,indicador: SF
# País AUT,indicador: GS
# País AUT,indicador: IN1
# País AUT,indicador: IN2
# País AUT,indicador: DXEF
# País AUT,indicador: D_F5
# País AUT,indicador: D_FL
# País AUT,indicador: PXEF
# País AUT,indicador: P_F5
# País AUT,indicador: P_F3
# País AUT,indicador: O_F4
# País AUT,indicador: O_F2
# País AUT,indicador: O_F81
# País AUT,indicador: RUE
# País AUT,indicador: R_F
# País BEL,indicador: CAB
# País BEL,indicador: CABXEF
# Finalizada etapa 1
# País BEL,indicador: KAB
# País BEL,indicador: FAB
# País BEL,indicador: FABXRRI
# País BEL,indicador: EO
# País BEL,indicador: SF
# País BEL,indicador: GS
# País BEL,indicador: IN1
# País BEL,indicador: IN2
# País BEL,indicador: DXEF
# País BEL,indicador: D_F5
# País BEL,indicador: D_FL
# País BEL,indicador: PXEF
# País BEL,indicador: P_F5
# País BEL,indicador: P_F3
# País BEL,indicador: O_F4
# País BEL,indicador: O_F2
# País BEL,indicador: O_F81
# País BEL,indicador: RUE
# País BEL,indicador: R_F
# País CZE,indicador: CAB
# País CZE,indicador: CABXEF
# Finalizada etapa 1
# País CZE,indicador: KAB
# País CZE,indicador: FAB
# País CZE,indicador: FABXRRI
# País CZE,indicador: EO
# País CZE,indicador: SF
# País CZE,indicador: GS
# País CZE,indicador: IN1
# País CZE,indicador: IN2
# País CZE,indicador: DXEF
# País CZE,indicador: D_F5
# País CZE,indicador: D_FL
# País CZE,indicador: PXEF
# País CZE,indicador: P_F5
# País CZE,indicador: P_F3
# País CZE,indicador: O_F4
# País CZE,indicador: O_F2
# País CZE,indicador: O_F81
# País CZE,indicador: RUE
# País CZE,indicador: R_F
# País HUN,indicador: CAB
# País HUN,indicador: CABXEF
# Finalizada etapa 1
# País HUN,indicador: KAB
# País HUN,indicador: FAB
# País HUN,indicador: FABXRRI
# País HUN,indicador: EO
# País HUN,indicador: SF
# País HUN,indicador: GS
# País HUN,indicador: IN1
# País HUN,indicador: IN2
# País HUN,indicador: DXEF
# País HUN,indicador: D_F5
# País HUN,indicador: D_FL
# País HUN,indicador: PXEF
# País HUN,indicador: P_F5
# País HUN,indicador: P_F3
# País HUN,indicador: O_F4
# País HUN,indicador: O_F2
# País HUN,indicador: O_F81
# País HUN,indicador: RUE
# País HUN,indicador: R_F
# País ROU,indicador: CAB
# País ROU,indicador: CABXEF
# Finalizada etapa 1
# País ROU,indicador: KAB
# País ROU,indicador: FAB
# País ROU,indicador: FABXRRI
# País ROU,indicador: EO
# País ROU,indicador: SF
# País ROU,indicador: GS
# País ROU,indicador: IN1
# País ROU,indicador: IN2
# País ROU,indicador: DXEF
# País ROU,indicador: D_F5
# País ROU,indicador: D_FL
# País ROU,indicador: PXEF
# País ROU,indicador: P_F5
# País ROU,indicador: P_F3
# País ROU,indicador: O_F4
# País ROU,indicador: O_F2
# País ROU,indicador: O_F81
# País ROU,indicador: RUE
# País ROU,indicador: R_F
# País PRT,indicador: CAB
# País PRT,indicador: CABXEF
# Finalizada etapa 1
# País PRT,indicador: KAB
# País PRT,indicador: FAB
# País PRT,indicador: FABXRRI
# País PRT,indicador: EO
# País PRT,indicador: SF
# País PRT,indicador: GS
# País PRT,indicador: IN1
# País PRT,indicador: IN2
# País PRT,indicador: DXEF
# País PRT,indicador: D_F5
# País PRT,indicador: D_FL
# País PRT,indicador: PXEF
# País PRT,indicador: P_F5
# País PRT,indicador: P_F3
# País PRT,indicador: O_F4
# País PRT,indicador: O_F2
# País PRT,indicador: O_F81
# País PRT,indicador: RUE
# País PRT,indicador: R_F
# País GRC,indicador: CAB
# País GRC,indicador: CABXEF
# Finalizada etapa 1
# País GRC,indicador: KAB
# País GRC,indicador: FAB
# País GRC,indicador: FABXRRI
# País GRC,indicador: EO
# País GRC,indicador: SF
# País GRC,indicador: GS
# País GRC,indicador: IN1
# País GRC,indicador: IN2
# País GRC,indicador: DXEF
# País GRC,indicador: D_F5
# País GRC,indicador: D_FL
# País GRC,indicador: PXEF
# País GRC,indicador: P_F5
# País GRC,indicador: P_F3
# País GRC,indicador: O_F4
# País GRC,indicador: O_F2
# País GRC,indicador: O_F81
# País GRC,indicador: RUE
# País GRC,indicador: R_F
# País BRA,indicador: CAB
# País BRA,indicador: CABXEF
# Finalizada etapa 1
# País BRA,indicador: KAB
# País BRA,indicador: FAB
# País BRA,indicador: FABXRRI
# País BRA,indicador: EO
# País BRA,indicador: SF
# País BRA,indicador: GS
# País BRA,indicador: IN1
# País BRA,indicador: IN2
# País BRA,indicador: DXEF
# País BRA,indicador: D_F5
# País BRA,indicador: D_FL
# País BRA,indicador: PXEF
# País BRA,indicador: P_F5
# País BRA,indicador: P_F3
# País BRA,indicador: O_F4
# País BRA,indicador: O_F2
# País BRA,indicador: O_F81
# País BRA,indicador: RUE
# País BRA,indicador: R_F
# País MEX,indicador: CAB
# País MEX,indicador: CABXEF
# Finalizada etapa 1
# País MEX,indicador: KAB
# País MEX,indicador: FAB
# País MEX,indicador: FABXRRI
# País MEX,indicador: EO
# País MEX,indicador: SF
# País MEX,indicador: GS
# País MEX,indicador: IN1
# País MEX,indicador: IN2
# País MEX,indicador: DXEF
# País MEX,indicador: D_F5
# País MEX,indicador: D_FL
# País MEX,indicador: PXEF
# País MEX,indicador: P_F5
# País MEX,indicador: P_F3
# País MEX,indicador: O_F4
# País MEX,indicador: O_F2
# País MEX,indicador: O_F81
# País MEX,indicador: RUE
# País MEX,indicador: R_F
# País ARG,indicador: CAB
# País ARG,indicador: CABXEF
# Finalizada etapa 1
# País ARG,indicador: KAB
# País ARG,indicador: FAB
# País ARG,indicador: FABXRRI
# País ARG,indicador: EO
# País ARG,indicador: SF
# País ARG,indicador: GS
# País ARG,indicador: IN1
# País ARG,indicador: IN2
# País ARG,indicador: DXEF
# País ARG,indicador: D_F5
# País ARG,indicador: D_FL
# País ARG,indicador: PXEF
# País ARG,indicador: P_F5
# País ARG,indicador: P_F3
# País ARG,indicador: O_F4
# País ARG,indicador: O_F2
# País ARG,indicador: O_F81
# País ARG,indicador: RUE
# País ARG,indicador: R_F
# País COL,indicador: CAB
# País COL,indicador: CABXEF
# Finalizada etapa 1
# País COL,indicador: FAB
# País COL,indicador: FABXRRI
# País COL,indicador: EO
# País COL,indicador: SF
# País COL,indicador: GS
# País COL,indicador: IN1
# País COL,indicador: IN2
# País COL,indicador: DXEF
# País COL,indicador: D_F5
# País COL,indicador: D_FL
# País COL,indicador: PXEF
# País COL,indicador: P_F5
# País COL,indicador: P_F3
# País COL,indicador: O_F4
# País COL,indicador: O_F2
# País COL,indicador: O_F81
# País COL,indicador: RUE
# País COL,indicador: R_F
# País CHL,indicador: CAB
# País CHL,indicador: CABXEF
# Finalizada etapa 1
# País CHL,indicador: KAB
# País CHL,indicador: FAB
# País CHL,indicador: FABXRRI
# País CHL,indicador: EO
# País CHL,indicador: SF
# País CHL,indicador: GS
# País CHL,indicador: IN1
# País CHL,indicador: IN2
# País CHL,indicador: DXEF
# País CHL,indicador: D_F5
# País CHL,indicador: D_FL
# País CHL,indicador: PXEF
# País CHL,indicador: P_F5
# País CHL,indicador: P_F3
# País CHL,indicador: O_F4
# País CHL,indicador: O_F2
# País CHL,indicador: O_F81
# País CHL,indicador: RUE
# País CHL,indicador: R_F
# País PER,indicador: CAB
# País PER,indicador: CABXEF
# Finalizada etapa 1
# País PER,indicador: KAB
# País PER,indicador: FAB
# País PER,indicador: FABXRRI
# País PER,indicador: EO
# País PER,indicador: SF
# País PER,indicador: GS
# País PER,indicador: IN1
# País PER,indicador: IN2
# País PER,indicador: DXEF
# País PER,indicador: D_F5
# País PER,indicador: D_FL
# País PER,indicador: PXEF
# País PER,indicador: P_F5
# País PER,indicador: P_F3
# País PER,indicador: O_F4
# País PER,indicador: O_F2
# País PER,indicador: O_F81
# País PER,indicador: RUE
# País PER,indicador: R_F
# País URY,indicador: CAB
# País URY,indicador: CABXEF
# Finalizada etapa 1
# País URY,indicador: KAB
# País URY,indicador: FAB
# País URY,indicador: FABXRRI
# País URY,indicador: EO
# País URY,indicador: SF
# País URY,indicador: GS
# País URY,indicador: IN1
# País URY,indicador: IN2
# País URY,indicador: DXEF
# País URY,indicador: D_F5
# País URY,indicador: D_FL
# País URY,indicador: PXEF
# País URY,indicador: P_F5
# País URY,indicador: P_F3
# País URY,indicador: O_F4
# País URY,indicador: O_F2
# País URY,indicador: O_F81
# País URY,indicador: RUE
# País URY,indicador: R_F
# Finalizada etapa 1
# País SGP,indicador: CAB
# País SGP,indicador: CABXEF
# Finalizada etapa 1
# País SGP,indicador: FAB
# País SGP,indicador: FABXRRI
# País SGP,indicador: EO
# País SGP,indicador: SF
# País SGP,indicador: GS
# País SGP,indicador: IN1
# País SGP,indicador: IN2
# País SGP,indicador: DXEF
# País SGP,indicador: PXEF
# País SGP,indicador: RUE
# País SGP,indicador: R_F
# País HKG,indicador: CAB
# País HKG,indicador: CABXEF
# Finalizada etapa 1
# País HKG,indicador: KAB
# País HKG,indicador: FAB
# País HKG,indicador: FABXRRI
# País HKG,indicador: EO
# País HKG,indicador: SF
# País HKG,indicador: GS
# País HKG,indicador: IN1
# País HKG,indicador: IN2
# País HKG,indicador: DXEF
# País HKG,indicador: D_F5
# País HKG,indicador: D_FL
# País HKG,indicador: PXEF
# País HKG,indicador: P_F5
# País HKG,indicador: P_F3
# País HKG,indicador: O_F4
# País HKG,indicador: O_F2
# País HKG,indicador: O_F81
# País HKG,indicador: RUE
# País HKG,indicador: R_F
# País THA,indicador: CAB
# País THA,indicador: CABXEF
# Finalizada etapa 1
# País THA,indicador: KAB
# País THA,indicador: FAB
# País THA,indicador: FABXRRI
# País THA,indicador: EO
# País THA,indicador: SF
# País THA,indicador: GS
# País THA,indicador: IN1
# País THA,indicador: IN2
# País THA,indicador: DXEF
# País THA,indicador: D_F5
# País THA,indicador: D_FL
# País THA,indicador: PXEF
# País THA,indicador: P_F5
# País THA,indicador: P_F3
# País THA,indicador: O_F4
# País THA,indicador: O_F2
# País THA,indicador: O_F81
# País THA,indicador: RUE
# País THA,indicador: R_F
# País MYS,indicador: CAB
# País MYS,indicador: CABXEF
# Finalizada etapa 1
# País MYS,indicador: KAB
# País MYS,indicador: FAB
# País MYS,indicador: FABXRRI
# País MYS,indicador: EO
# País MYS,indicador: SF
# País MYS,indicador: GS
# País MYS,indicador: IN1
# País MYS,indicador: IN2
# País MYS,indicador: DXEF
# País MYS,indicador: D_F5
# País MYS,indicador: D_FL
# País MYS,indicador: PXEF
# País MYS,indicador: P_F5
# País MYS,indicador: P_F3
# País MYS,indicador: O_F4
# País MYS,indicador: O_F2
# País MYS,indicador: O_F81
# País MYS,indicador: RUE
# País MYS,indicador: R_F
# País VNM,indicador: CAB
# País VNM,indicador: CABXEF
# Finalizada etapa 1
# País VNM,indicador: KAB
# País VNM,indicador: FAB
# País VNM,indicador: FABXRRI
# País VNM,indicador: EO
# País VNM,indicador: GS
# País VNM,indicador: IN1
# País VNM,indicador: IN2
# País VNM,indicador: DXEF
# País VNM,indicador: D_F5
# País VNM,indicador: D_FL
# País VNM,indicador: PXEF
# País VNM,indicador: P_F5
# País VNM,indicador: P_F3
# País VNM,indicador: O_F4
# País VNM,indicador: O_F2
# País VNM,indicador: O_F81
# País VNM,indicador: RUE
# País VNM,indicador: R_F
# País IDN,indicador: CAB
# País IDN,indicador: CABXEF
# Finalizada etapa 1
# País IDN,indicador: KAB
# País IDN,indicador: FAB
# País IDN,indicador: FABXRRI
# País IDN,indicador: EO
# País IDN,indicador: SF
# País IDN,indicador: GS
# País IDN,indicador: IN1
# País IDN,indicador: IN2
# País IDN,indicador: DXEF
# País IDN,indicador: D_F5
# País IDN,indicador: D_FL
# País IDN,indicador: PXEF
# País IDN,indicador: P_F5
# País IDN,indicador: P_F3
# País IDN,indicador: O_F4
# País IDN,indicador: O_F2
# País IDN,indicador: O_F81
# País IDN,indicador: RUE
# País IDN,indicador: R_F
# País PHL,indicador: CAB
# País PHL,indicador: CABXEF
# Finalizada etapa 1
# País PHL,indicador: KAB
# País PHL,indicador: FAB
# País PHL,indicador: FABXRRI
# País PHL,indicador: EO
# País PHL,indicador: SF
# País PHL,indicador: GS
# País PHL,indicador: IN1
# País PHL,indicador: IN2
# País PHL,indicador: DXEF
# País PHL,indicador: D_F5
# País PHL,indicador: D_FL
# País PHL,indicador: PXEF
# País PHL,indicador: P_F5
# País PHL,indicador: P_F3
# País PHL,indicador: O_F4
# País PHL,indicador: O_F2
# País PHL,indicador: O_F81
# País PHL,indicador: RUE
# País PHL,indicador: R_F
# País SAU,indicador: CAB
# País SAU,indicador: CABXEF
# Finalizada etapa 1
# País SAU,indicador: KAB
# País SAU,indicador: FAB
# País SAU,indicador: FABXRRI
# País SAU,indicador: EO
# País SAU,indicador: SF
# País SAU,indicador: GS
# País SAU,indicador: IN1
# País SAU,indicador: IN2
# País SAU,indicador: DXEF
# País SAU,indicador: PXEF
# País SAU,indicador: P_F5
# País SAU,indicador: P_F3
# País SAU,indicador: O_F4
# País SAU,indicador: O_F2
# País SAU,indicador: O_F81
# País SAU,indicador: RUE
# País SAU,indicador: R_F
# Finalizada etapa 1
# País QAT,indicador: CAB
# País QAT,indicador: CABXEF
# Finalizada etapa 1
# País QAT,indicador: KAB
# País QAT,indicador: FAB
# País QAT,indicador: FABXRRI
# País QAT,indicador: EO
# País QAT,indicador: SF
# País QAT,indicador: GS
# País QAT,indicador: IN1
# País QAT,indicador: IN2
# País QAT,indicador: DXEF
# País QAT,indicador: PXEF
# País QAT,indicador: P_F5
# País QAT,indicador: P_F3
# País QAT,indicador: O_F4
# País QAT,indicador: O_F2
# País QAT,indicador: O_F81
# País QAT,indicador: RUE
# País QAT,indicador: R_F
# País KWT,indicador: CAB
# País KWT,indicador: CABXEF
# Finalizada etapa 1
# País KWT,indicador: KAB
# País KWT,indicador: FAB
# País KWT,indicador: FABXRRI
# País KWT,indicador: EO
# País KWT,indicador: SF
# País KWT,indicador: GS
# País KWT,indicador: IN1
# País KWT,indicador: IN2
# País KWT,indicador: DXEF
# País KWT,indicador: D_F5
# País KWT,indicador: D_FL
# País KWT,indicador: PXEF
# País KWT,indicador: P_F5
# País KWT,indicador: P_F3
# País KWT,indicador: O_F4
# País KWT,indicador: O_F2
# País KWT,indicador: O_F81
# País KWT,indicador: RUE
# País KWT,indicador: R_F
# Finalizada etapa 1
# País ISR,indicador: CAB
# País ISR,indicador: CABXEF
# Finalizada etapa 1
# País ISR,indicador: KAB
# País ISR,indicador: FAB
# País ISR,indicador: FABXRRI
# País ISR,indicador: EO
# País ISR,indicador: SF
# País ISR,indicador: GS
# País ISR,indicador: IN1
# País ISR,indicador: IN2
# País ISR,indicador: DXEF
# País ISR,indicador: D_F5
# País ISR,indicador: D_FL
# País ISR,indicador: PXEF
# País ISR,indicador: P_F5
# País ISR,indicador: P_F3
# País ISR,indicador: O_F4
# País ISR,indicador: O_F2
# País ISR,indicador: O_F81
# País ISR,indicador: RUE
# País ISR,indicador: R_F
# País NOR,indicador: CAB
# País NOR,indicador: CABXEF
# Finalizada etapa 1
# País NOR,indicador: KAB
# País NOR,indicador: FAB
# País NOR,indicador: FABXRRI
# País NOR,indicador: EO
# País NOR,indicador: SF
# País NOR,indicador: GS
# País NOR,indicador: IN1
# País NOR,indicador: IN2
# País NOR,indicador: DXEF
# País NOR,indicador: D_F5
# País NOR,indicador: D_FL
# País NOR,indicador: PXEF
# País NOR,indicador: P_F5
# País NOR,indicador: P_F3
# País NOR,indicador: O_F4
# País NOR,indicador: O_F2
# País NOR,indicador: O_F81
# País NOR,indicador: RUE
# País NOR,indicador: R_F
# País RUS,indicador: CAB
# País RUS,indicador: CABXEF
# Finalizada etapa 1
# País RUS,indicador: KAB
# País RUS,indicador: FAB
# País RUS,indicador: FABXRRI
# País RUS,indicador: EO
# País RUS,indicador: SF
# País RUS,indicador: GS
# País RUS,indicador: IN1
# País RUS,indicador: IN2
# País RUS,indicador: DXEF
# País RUS,indicador: D_F5
# País RUS,indicador: D_FL
# País RUS,indicador: PXEF
# País RUS,indicador: P_F5
# País RUS,indicador: P_F3
# País RUS,indicador: O_F4
# País RUS,indicador: O_F2
# País RUS,indicador: O_F81
# País RUS,indicador: RUE
# País RUS,indicador: R_F
# País ZAF,indicador: CAB
# País ZAF,indicador: CABXEF
# Finalizada etapa 1
# País ZAF,indicador: KAB
# País ZAF,indicador: FAB
# País ZAF,indicador: FABXRRI
# País ZAF,indicador: EO
# País ZAF,indicador: SF
# País ZAF,indicador: GS
# País ZAF,indicador: IN1
# País ZAF,indicador: IN2
# País ZAF,indicador: DXEF
# País ZAF,indicador: D_F5
# País ZAF,indicador: D_FL
# País ZAF,indicador: PXEF
# País ZAF,indicador: P_F5
# País ZAF,indicador: P_F3
# País ZAF,indicador: O_F4
# País ZAF,indicador: O_F2
# País ZAF,indicador: O_F81
# País ZAF,indicador: RUE
# País ZAF,indicador: R_F
# País EGY,indicador: CAB
# País EGY,indicador: CABXEF
# Finalizada etapa 1
# País EGY,indicador: KAB
# País EGY,indicador: FAB
# País EGY,indicador: FABXRRI
# País EGY,indicador: EO
# País EGY,indicador: SF
# País EGY,indicador: GS
# País EGY,indicador: IN1
# País EGY,indicador: IN2
# País EGY,indicador: DXEF
# País EGY,indicador: D_F5
# País EGY,indicador: D_FL
# País EGY,indicador: PXEF
# País EGY,indicador: P_F5
# País EGY,indicador: P_F3
# País EGY,indicador: O_F4
# País EGY,indicador: O_F2
# País EGY,indicador: O_F81
# País EGY,indicador: RUE
# País EGY,indicador: R_F
# País NGA,indicador: CAB
# País NGA,indicador: CABXEF
# Finalizada etapa 1
# País NGA,indicador: FAB
# País NGA,indicador: FABXRRI
# País NGA,indicador: EO
# País NGA,indicador: SF
# País NGA,indicador: GS
# País NGA,indicador: IN1
# País NGA,indicador: IN2
# País NGA,indicador: DXEF
# País NGA,indicador: D_F5
# País NGA,indicador: D_FL
# País NGA,indicador: PXEF
# País NGA,indicador: P_F5
# País NGA,indicador: P_F3
# País NGA,indicador: O_F4
# País NGA,indicador: O_F2
# País NGA,indicador: O_F81
# País NGA,indicador: RUE
# País NGA,indicador: R_F
# País GHA,indicador: CAB
# País GHA,indicador: CABXEF
# Finalizada etapa 1
# País GHA,indicador: KAB
# País GHA,indicador: FAB
# País GHA,indicador: FABXRRI
# País GHA,indicador: EO
# País GHA,indicador: SF
# País GHA,indicador: GS
# País GHA,indicador: IN1
# País GHA,indicador: IN2
# País GHA,indicador: DXEF
# País GHA,indicador: D_F5
# País GHA,indicador: D_FL
# País GHA,indicador: PXEF
# País GHA,indicador: P_F5
# País GHA,indicador: P_F3
# País GHA,indicador: O_F4
# País GHA,indicador: O_F2
# País GHA,indicador: O_F81
# País GHA,indicador: RUE
# País GHA,indicador: R_F
# Finalizada etapa 1
#   COUNTRY BOP_ACCOUNTING_ENTRY INDICATOR UNIT FREQUENCY TIME_PERIOD  \
# 0     USA              NETCD_T       CAB  USD         Q     2000-Q1
# 1     USA              NETCD_T       CAB  USD         Q     2000-Q2
# 2     USA              NETCD_T       CAB  USD         Q     2000-Q3
# 3     USA              NETCD_T       CAB  USD         Q     2000-Q4
# 4     USA              NETCD_T       CAB  USD         Q     2001-Q1
#
#           value  index
# 0 -8.458500e+10    NaN
# 1 -9.610400e+10    NaN
# 2 -1.149650e+11    NaN
# 3 -1.062740e+11    NaN
# 4 -9.645400e+10    NaN
