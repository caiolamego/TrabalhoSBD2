# %%
import pandas as pd

df_bop = pd.read_csv("BOP.csv")
df_er = pd.read_csv("ER.csv")
df_iip = pd.read_csv("IIP.csv")
df_irfcl = pd.read_csv("IRFCL.csv")



print(len(df_bop))
print(len(df_er))
print(len(df_iip))
print(len(df_irfcl))
# Out:
# 180804
# 79065
# 96247
# 107805
